# %%
image_url = "https://images.pexels.com/photos/36753/flower-purple-lical-blosso.jpg?w=940&h=650&auto=compress&cs=tinysrgb"

# %%
import requests

image_binary = requests.get(image_url).content

with open("flower.jpg", "wb") as f:
    f.write(image_binary)

# %%
from PIL import Image # Pillow

flower_image = Image.open("flower.jpg")

# %%
flower_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=940x622 at 0x233B2828860>

# %%
from pilkit.processors import Thumbnail

processor = Thumbnail(width=300, height=300)

# %%
thumb_image = processor.process(flower_image)

# %%
thumb_image
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x233B22FCCC0>

# %%
thumb_image.save("thumb-300x300.png")

thumb_image.save("thumb-300x300.jpg", quality=10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Coding\anaconda\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     601     try:
# --> 602         rawmode = RAWMODE[im.mode]
#     603     except KeyError:
#
# KeyError: 'RGBA'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-8748f1368e64> in <module>()
#       1 thumb_image.save("thumb-300x300.png")
#       2
# ----> 3 thumb_image.save("thumb-300x300.jpg", quality=10)
#
# D:\Coding\anaconda\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    1891
#    1892         try:
# -> 1893             save_handler(self, fp, filename)
#    1894         finally:
#    1895             # do what we can to clean up
#
# D:\Coding\anaconda\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     602         rawmode = RAWMODE[im.mode]
#     603     except KeyError:
# --> 604         raise IOError("cannot write mode %s as JPEG" % im.mode)
#     605
#     606     info = im.encoderinfo
#
# OSError: cannot write mode RGBA as JPEG
